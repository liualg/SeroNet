# %%
import re

# %%
a = '​JSON Summary Description'

# %%
re.sub('[^a-zA-Z0-9 \n\.]',' ',a).strip()
# Out:
# 'JSON Summary Description'

# %%
re.replace()

# %%
import pandas as pd

# %%
a = pd.read_excel("/Users/liualg/Library/CloudStorage/OneDrive-NationalInstitutesofHealth/Curation channel/ImmPort Uploads/Data Release Updates_/DR48/DR48_update-ImmPortxlsx.xlsx",
                 sheet_name = 'Experiments')

# %%
b = pd.read_excel('/Users/liualg/Documents/GitHub/SeroNet/seronetTemplates/dictionary/Seronet_Study_Descriptors_v1.3_EVS.xlsx',
                 sheet_name = 'EVS Mapping')

# %%
b_dict = dict(zip(b['SeroNet PT'],b['NCIt Def']))
b_dict
# Out:
# {'Species': 'The binomial name of the organism that is the experimental study subject.',
#  'Assay Type': 'The type(s) of biological assay(s) that were run as part of the study.',
#  'Performance Metrics Included': 'Indicator as to whether performance metrics are included when study submits results from biological assay(s).',
#  'Virus Target': 'The virus(es) targeted by the serology assay.',
#  'Antibody Isotype': 'The antibody isotype to SARS-CoV-2 detected or quantified by the serology assay.',
#  'SARS-CoV-2 Antigen': 'The SARS-CoV-2 antigen or epitope that is interrogated by the serology assay.',
#  'FNL SARS-CoV-2 Antigen Used': 'Indicator as to whether SARS-CoV-2 antigen supplied by the Frederick National Laboratory was used in the serology assay.',
#  'Assay Use': 'A coded value that indicates how the serology assay may be used.',
#  'Assay Reporting Format': 'A coded value that signifies the format in which the serology assay reports results.',
#  'Reporting Units': 'The units in which the serology assay reports its results.',
#  'Biospecimen Type': 'The type of biospecimen(s) and host cell type(s) analyzed in the study.',
#  'Biospecimen Collection Point': 'The phase in the infection or vaccination continuum that a biospecimen was collected from study subjects.',
#  'In Silico Model Type': 'The type(s) of in silico models that were developed as part of the study.',
#  'Organoid Model': 'The name of the organoid model that is the experimental study subject.',
#  'Cell Line': 'The name of the tissue culture model or cell line that is the experimental study subject.',
#  'Primary Institution Name': 'Full official name of the institution or organization at which the study was conducted.',
#  'Collaborating Institution Name': 'Full official name of the institution or organization that participated in, but did not lead, the study.',
#  'Virus Variant': 'The label assigned by the World Health Organization to the virus variant(s) being investigated in the study.',
#  'Study Name': 'Brief yet descriptive title of the study.',
#  'Study Objective': 'Short narrative describing the principal objectives of the study.',
#  'Controlled Access': 'Indicator as to whether the study has controlled access data. Controlled access data are data that require dbGaP access.',
#  'dbGaP Registration Number': 'Unique numerical identifier assigned to the study as of its registration with dbGaP.',
#  'Publication Title': 'The official title of the manuscript generated by the study.',
#  'PubMed ID': 'Unique numerical identifier associated with each publication generated by the study, as assigned by PubMed.',
#  'Study Data Repository': 'A database in which study data are stored for access and use by the scientific community.',
#  'Study Identifier': 'Human-friendly alpha-numeric identifier by which the study is referenced by at the study data repository.',
#  'SeroNet Award Number': 'Unique identifier by which the SeroNet grant used to fund the study can be referenced.',
#  'Study Type': 'The nature of the investigation being conducted by a study. ',
#  'Enrollment Start Date': 'Date upon which the first study subject was enrolled into the study.',
#  'Enrollment End Date': 'Date upon which the last study subject was enrolled into the study.',
#  'Keyword': 'A word or small set of words designed to convey the subject of a study. Keywords may be provided to capture unique features of a study that are not easily described by the other study descriptors.',
#  'Study Location*': 'The geographic location from which study subjects have been recruited. This may be denoted by entering the broad geographic regions(s), and/or the states and territories, within the United States, or the name of the countries from which the study subjects have been recruited. ',
#  'Clinical Outcome Measure': 'A measurement or observation used to measure the effect of experimental variables in a study. For observational studies outcome measures describe patterns of diseases or traits, or associations with study variables such as exposures, risk factors, or treatment.',
#  'Clinical Study Design': 'A coded value that represents the plan of how a study will be performed in order to represent the phenomenon under examination, to answer the research questions that have been asked, and defining the methods of data analysis.\xa0',
#  'Survey Instruments Shared': 'An indicator signifying if study has shared its case report forms, questionnaires and other survey instruments for broad use within the scientific community',
#  'Study Population': 'A group of individuals taken from the general population who share a set of common characteristics, such as age, sex, or health condition, precisely defined in the study protocol. This is a population to which the study results could be reasonably generalized.',
#  'Measured Behavioral or Psychological Factor': 'The behavioral or psychological factor(s) being measured as part of the study.',
#  'Measured Social Factor': 'The social factor(s) being measured as part of the study.',
#  'Number of Study Subjects': 'The total number of study subjects included in the study.',
#  'Clinical  and Demographic Data Provenance': 'The process and methodology by which clinical and demographic data were collected by the study.',
#  'Minimum Age': 'Actual age of youngest subject.',
#  'Maximum Age': 'Actual age of oldest subject.',
#  'Pediatric Study Subjects Included': 'Indicator signifying if study subjects younger than 18 years of age have been included in the study.',
#  'Geriatric Study Subjects Included': 'Indicator signifying if study subjects 65 years of age or older have been included in the study. ',
#  'Pregnant Study Subjects Included': 'Indicator signifying if pregnant study subjects have been included in the study.',
#  'Sex at Birth': 'The sex of study subjects. Sex is the phenotypic expression of chromosomal makeup that defines a study subject as male, female, or other. ',
#  'Race ': 'The race of study subjects included in the study. Race is a geographic ancestral origin category that is assigned to a population group based mainly on physical characteristics that are thought to be distinct and inherent.',
#  'Ethnicity': 'The ethnicity of study subjects included in the study. Ethnicity is an arbitrary classification of the social group a person belongs to, and either identifies with or is identified with by others, as a result of a complex of cultural, biological, geographical and other factors such as linguistic, dietary and religion traditions; ancestry, background, allegiance, or association; and physical characteristics traditionally associated with race.',
#  'Demographic Data Type Collected': 'Demographic data types that have been collected on the study subjects.',
#  'SARS-CoV-2 History': 'The history of SARS-CoV-2 infection and/or vaccination of the study subjects.',
#  'SARS-CoV-2 Vaccine Type': 'The SARS-CoV-2 vaccine administered to study subjects included in the study.',
#  'SARS-CoV-2 Symptoms': 'A coded value that signifies if, and for how long, study subjects were symptomatic for SARS-CoV-2.',
#  'WHO Disease Severity Scale': 'Indicator that signifies if study has used the WHO disease severity scale to record disease severity in study subjects.',
#  'COVID-19 Disease Severity': 'A coded value that represents the severity of disease in study subjects included in the study.',
#  'SARS-CoV-2 Antibodies Measured': 'Indicator signifying if SARS-CoV-2 antibodies were either detected or quantified in study subjects.',
#  'Reported Health Condition*': 'Indicator signifying if following health condition or medical problems were detected among the study subjects.',
#  'Post COVID-19 Symptoms': 'New, recurring, or ongoing symptoms and clinical findings four or more weeks after infection, sometimes after initial symptom recovery.',
#  'COVID-19 Complications': 'Disease or disorder that occurs during the course of, or because of COVID-19 infection or treatment.'}

# %%
for exps in a['Name']:
    print(b_dict.get(exps))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
